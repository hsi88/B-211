# %%
import seaborn as sns
sns.__version__
import pandas as pd

# %%
iris

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
iris.columns[1]
# Out:
# 'sepal_width'

# %%
iris['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
1. Your biology professor has a pet project studying irises. They would like you to use the
iris dataset from Seaborn to perform a thorough graphical analysis. Provide both the
figures (in PNG format) and code for creating the following plots. (Be sure to make sure
axes are labeled, figures have titles, and keys are included.)

# %%
#a. Look at the distributions for each of the traits (sepal length, sepal width, petal length, and petal width). 

def his(column):
 plt.hist(iris[column], 30)
 plt.title('distirbution of ' + column, size = 20)
 plt.xlabel(column, size =20)
 plt.ylabel('frenquency',size=20)
 
 plt.savefig('distirbution of ' + column)
 plt.show()
 
for x in iris.columns[0:4]:
  his(x)

# %%
# b. Create a categorical plot for each trait by species
def categorical(tar):
  y=iris[iris.columns[tar]]
  rect = plt.bar(iris[iris.columns[4]], y)
  
#title, label
  plt.title("category for " + iris.columns[tar], size=20)
  plt.xlabel(iris.columns[tar],size=20)
  plt.ylabel('frenquency', size = 20)
  plt.savefig("category for " + iris.columns[tar], dpi=100)
#grid
  plt.minorticks_on() 
  plt.grid(which='major', linestyle='-', color='red')
  plt.grid(which='minor', linestyle=':', color='black')
 
  plt.show()

#iterate the column
for tar in range(4):
  categorical(tar)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-729f57385630> in <module>()
# ----> 1 bar.get_height()
#
# NameError: name 'bar' is not defined

# %%
#c. Create relational plots between trait pairs (sepal length vs sepal width, petal
# length vs petal width), include a way of distinguishing by species. 

sns.scatterplot(iris['sepal_length'], iris['petal_width'], hue=iris['species'])
plt.title('trait pairs (sepal length vs sepal width)') 
plt.savefig('trait pairs (sepal length vs sepal width)')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(iris['petal_length'], iris['petal_width'], hue=iris['species'])
plt.title('trait pairs (petal length vs petal width)')
plt.savefig('trait pairs (petal length vs petal width))')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Based upon your analysis, which species are most related? Support your claim. 
print('versicolar and virginica are more related, they are more close to each other')

# %%
2. Your local gym is helping a nearby elementary school by providing diet and workout data
for their various patrons. Import the exercise data from Seaborn. Provide both the figures
(in PNG format) and code for creating the following plots. #'
# Out:
# 'petal_length'

# %%
import seaborn as sns
ex = sns.load_dataset('exercise')
ex
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
a. Create a heatmap for the participants, workout time, and pulse. (Hint use the pivot
command from Pandas to get the data in appropriate format)
# Out:
#   File "<ipython-input-13-7849babb3ab9>", line 1
#     a. Create a heatmap for the participants, workout time, and pulse. (Hint use the pivot
#               ^
# SyntaxError: invalid syntax

# %%
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 85    85
# 86    86
# 87    87
# 88    88
# 89    89
# Name: Unnamed: 0, Length: 90, dtype: int64

# %%
df = pd.pivot_table(data=sns.load_dataset("exercise"),
                    index='id',
                    values='pulse',
                    columns='time')


df
# Out:
# time  1 min  15 min  30 min
# id
# 1        85      85      88
# 2        90      92      93
# 3        97      97      94
# 4        80      82      83
# 5        91      92      91
# 6        83      83      84
# 7        87      88      90
# 8        92      94      95
# 9        97      99      96
# 10      100      97     100
# 11       86      86      84
# 12       93     103     104
# 13       90      92      93
# 14       95      96     100
# 15       89      96      95
# 16       84      86      89
# 17      103     109      90
# 18       92      96     101
# 19       97      98     100
# 20      102     104     103
# 21       93      98     110
# 22       98     104     112
# 23       98     105      99
# 24       87     132     120
# 25       94     110     116
# 26       95     126     143
# 27      100     126     140
# 28      103     124     140
# 29       94     135     130
# 30       99     111     150

# %%
plt.figure(figsize = (16,8))

sns.heatmap(df,annot=True,  cmap="YlGnBu") 
plt.title('heatmap of pulse ')
plt.savefig('heatmap of pulse ')

# %%
b. Create a categorical plot for pulse by diet and by type of exercise.

# %%
plt.figure(figsize = (16,8))
sns.stripplot(data=ex,x="diet", y="pulse")
stitle = 'pulse of different diet'
plt.title('pulse of different diet')
plt.savefig(stitle)

# %%
plt.figure(figsize = (16,8))
sns.stripplot(data=ex,x="kind", y="pulse")
plt.title('pulse of different exercise')
plt.savefig('pulse of different exercise')

# %%
# c. Give a brief explanation of the meaning of the 3 graphs to the elementary students.

print('for you helth, take high fat food which may cause high pulse' 
'and please be aware that running may cause high pulse ')
# Out:
# for you helth, take high fat food which may cause high pulseand please be aware that running may cause high pulse
